# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py
import math
import tensorflow as tf
import os
import shutil
from skimage.io import imread
from photutils.background import Background2D, MedianBackground
from photutils.segmentation import detect_sources
from astropy.convolution import convolve
from photutils.segmentation import make_2dgaussian_kernel
from photutils.segmentation import SourceCatalog
from photutils.segmentation import deblend_sources
import to_rgb

# %%
def is_blended_improved(file):
    image = to_rgb.dr2_rgb(file,['g','r','z'])
    img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    data=img

    bkg_estimator = MedianBackground()
    bkg = Background2D(data, (50, 50), filter_size=(3, 3),
                       bkg_estimator=bkg_estimator)
    data -= bkg.background  # subtract the background
    threshold = 1.5 * bkg.background_rms

    kernel = make_2dgaussian_kernel(3.0, size=5)  # FWHM = 3.0
    convolved_data = convolve(data, kernel)
    half_x = int(data.shape[0] / 2)
    half_y = int(data.shape[1] / 2)
    # 检测到的源x
    segment_map = detect_sources(convolved_data, threshold, npixels=10)
    pre_label = segment_map.data[half_x][half_y]

    pre_cat = SourceCatalog(data, segment_map, convolved_data=convolved_data)
    pre_object = pre_cat.get_labels(pre_label).to_table()


    segm_deblend = deblend_sources(convolved_data, segment_map,
                                   npixels=10, nlevels=90, contrast=0.000001,  # 改参数
                                   progress_bar=False)
    cat = SourceCatalog(data, segm_deblend, convolved_data=convolved_data)
    tbl = cat.to_table()
    label = segm_deblend.data[half_x][half_y]
    object = cat.get_labels(label).to_table()
    
    
    if len(tbl) == 1:
        return "OK"

    else:
        return "NO"#重叠

# %%
def is_blended(file):
    img = to_rgb.dr2_rgb(file,['g','r','z'])#   228
    img=tf.image.central_crop(img, 0.5)
    img=np.array(tf.image.resize(img, (152, 152)))
    #plt.imshow(img)
    #plt.show()
    
    inputMat = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    a, thresholded = cv2.threshold(inputMat, 0.4, 255, cv2.THRESH_BINARY)
    
    edges = cv2.Canny(thresholded.astype(np.uint8), 30, 90)
    
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    if len(contours)==0:
        #print('不是混叠星系')
        return 'OK'
        
    else:
        center_contour = max(contours, key=cv2.contourArea)

        center_convex_hull = cv2.convexHull(center_contour)

        center_contour_area = cv2.contourArea(center_contour)
        center_convex_hull_area = cv2.contourArea(center_convex_hull)

        img_with_contour = np.copy(edges)
        cv2.drawContours(img_with_contour, [center_contour], -1, 255, 1)
        cv2.drawContours(img_with_contour, [center_convex_hull], -1, 255, 1)
        
        if center_convex_hull_area==0:
            return 'NO'
        
        bz=center_contour_area/center_convex_hull_area

        if (bz >=0.93) and (bz <= 1.1):
            return 'OK' #不是混叠
        else:
            return 'NO' #是混叠

        #plt.imshow(img_with_contour, cmap='gray')
        #plt.show()

# %%
def iterative_threshold(image):
    # 获取图像的最大和最小灰度值
    cmax = np.max(image)
    cmin = np.min(image)
    # print(cmin)
    # 初始化阈值为 (cmax + cmin) / 2
    T_prev = (cmax + cmin) / 2
    T_next = 0
    
    while T_prev != T_next:
        # 根据当前阈值将图像分为前景和背景两类
        foreground = image >= T_prev
        background = image < T_prev
        
        # 计算前景和背景的平均灰度值
        cobj = np.mean(image[foreground])
        cbkg = np.mean(image[background])
        
        # 更新阈值
        T_next = (cobj + cbkg) / 2
        T_prev = T_next
        # print("T_next:",T_next)
    
    return T_prev

def find_enclosing_circle(image):
    # 使用 connectedComponentsWithStats 获取连通区域信息
    num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(image)

    # 选择要处理的目标区域，这里假设选择面积最大的非背景区域
    target_label = np.argmax(stats[1:, cv2.CC_STAT_AREA]) + 1

    # 使用 np.where 找到目标连通区域的所有像素坐标
    target_pixels = np.where(labels == target_label)

    # 获取目标连通区域的坐标
    target_coordinates = np.column_stack(target_pixels)

    # 使用 cv2.minEnclosingCircle 计算最小外接圆的圆心坐标和半径
    center, radius = cv2.minEnclosingCircle(target_coordinates)

    # 将圆心坐标和半径返回
    center = (int(center[0]), int(center[1]))
    radius = int(radius)
    return center, radius

def overlap_detection(processed_image):
    
    img_rgb=np.transpose(processed_image,(1,2,0))
    accurate = True  # 结果是否准确

    inputMat = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
    
    # 图像二值化 ：
    threshold_value = iterative_threshold(inputMat)
    
    _, thresholded = cv2.threshold(inputMat, threshold_value, 255, cv2.THRESH_BINARY)
    thresholded=thresholded.astype(np.uint8)
    
    # 求连通域
    num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresholded)

    if num_labels>2:
        accurate = False
    # plt.imshow(thresholded, cmap='gray')
    # plt.axis('off')
    # plt.show()

    return accurate

# %%
def mask_ellipse_center(image, Expansion_scale=1.4,accuracy=5):
    img_rgb=to_rgb.dr2_rgb(image,['g','r','z'])
    accurate = True  # 结果是否准确
    reason = None    # 不准确的原因
    end_image = np.transpose(image,(1,2,0))
    
    # 1.转化成灰度图像：
    inputMat = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
    
    # 2.图像二值化 ：
    
    threshold_value = iterative_threshold(inputMat)
    # print("threshold_value:",threshold_value )
    _, thresholded = cv2.threshold(inputMat, threshold_value, 255, cv2.THRESH_BINARY)
    
    # 3.边缘检测(连通域的边缘)：
    edges = cv2.Canny(thresholded.astype(np.uint8), 30, 90)
    # 轮廓提取（每个连通域的轮廓为一个contours）：
    contours, hierarchy = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    # 在图像上绘制轮廓：
    # contour_image = cv2.drawContours(rgb, contours, -1, (0, 255, 0), 2) 
    
     
    end_ellipse = None   # 存储拟合到的中心椭圆
    fit_rate = None   # 存储拟合与实际面积比值
    center_x = inputMat.shape[1]/2
    center_y = inputMat.shape[0]/2
    min_distance = 9999
    
    # 4.将每个星体拟合成一个椭圆，并保存图像中心的椭圆：
    for contour in contours:
        
        # 轮廓包含的点数小于5则无法拟合：
        if len(contour) >= 5:
            
            # 拟合最小椭圆
            ellipse = cv2.fitEllipse(contour)
            
            # 椭圆参数
            center_e_x = ellipse[0][0]
            center_e_y = ellipse[0][1]
            a = ellipse[1][0] / 2   # 长轴
            b = ellipse[1][1] / 2
            angle = ellipse[2]

            # 检查长轴和短轴是否为零
            if a > 3 and b >3:
                distance = math.sqrt((center_e_x - center_x) ** 2 + (center_e_y - center_y) ** 2)
                operator = ((center_x - center_e_x) ** 2 / a ** 2) + ((center_y - center_e_y) ** 2 / b ** 2)
                
                # 判断给定点是否在椭圆内
                if operator <= 1:
                    # 判断给定点距离原点距离
                    if distance <= min_distance:
                        min_distance = distance
                        end_ellipse=ellipse

                        #计算拟合与实际面积比值：
                        area_ellipse = math.pi * a * b    # 计算椭圆的面积
                        area_contour = cv2.contourArea(contour)  # 计算轮廓包含的面积
                        fit_rate = area_contour/area_ellipse

    
    
    # 5.遮盖其余图像
    # 定义掩码
    mask = np.zeros(img_rgb.shape[:2], dtype=np.uint8)
    center = None
    radius = None
    # 判断有无找到中心星体：
    if min_distance<accuracy: 
 
        # 定义椭圆参数
        center = (int(end_ellipse[0][0]), int(end_ellipse[0][1]))
        axes = (int(end_ellipse[1][0] / 2 * Expansion_scale), int(end_ellipse[1][1] / 2 * Expansion_scale))
        angle = int(end_ellipse[2])

        # 在掩码上绘制椭圆区域（白色部分）
        cv2.ellipse(mask, center, axes, angle, 0, 360, 255, -1)
            
 
        # 黑色遮盖椭圆范围外的部分
        end_image = cv2.bitwise_and(end_image, end_image, mask=mask)
        # print(thresholded.shape)
        # print(thresholded)
        # print(mask.shape)
        thresholded=thresholded.astype(np.uint8)
        thresholded_mask = cv2.bitwise_and(thresholded, mask)
        center, radius = find_enclosing_circle(thresholded_mask)
        # print(center, radius)
        
    else:
        # 在图像中心点没有找到星体
        accurate = False
        reason = f"Minimum distance greater than {accuracy}:{min_distance}"
        
    
    result = {
        'image':np.transpose(end_image,(2,0,1)),
        'accurate': accurate,
        'reason': reason,
        'fit_rates': fit_rate,
        'ellipses':end_ellipse,
        'distance':min_distance,
        'center':center,
        'radius':radius
    }
    return result

# %%
def process_and_save_data(h5_file_path,radius_Limit=[0,23], new_h5_file_path=None,new_csv_file_path=None,save_old = True):
    
    # 打开H5旧文件，指定读模式 'r'，允许对文件进行读取
    with h5py.File(h5_file_path, 'r') as h5_file:
        # 检查'image' key是否存在
        if 'images' in h5_file:
            # 获取'image' key对应的数据集
            dataset = h5_file['images']
            # 获取所有的key用于将已有参数复制到新图像
            keys = list(h5_file.keys())
            
            processed_images = []  # 保存处理过的图像
            distances = []    # 保存拟合的椭圆的准确度，越小越好
            circles_radius = []   # 保存外接圆半径（像素点）
            circles_arc = []  # 角秒
            selected_indices = []  #保存符合的索引
            data_dict = {}

            #计数
            num_tol = 0
            num_success = 0
            num_six = 0
            num_conform  = 0

            for i, image in enumerate(dataset):
                # 调用函数得到新图像等数据
                result = mask_ellipse_center(image)
                #result2 = is_blended(image)
                num_tol+=1

                #成功识别
                #if result['accurate'] and result2 == 'OK':
                if result['accurate']:
                    num_success+=1
                    processed_image = result['image']   #图像数据
                    distance = result['distance']       #椭圆圆心距离原点距离
                    circle_radius = result['radius']    # 外接圆半径
                    circle_arc = circle_radius*0.262
                
                    # 符合6角秒
                    if circle_radius >radius_Limit[0] and circle_radius<radius_Limit[1]:
                    #if oval_size >radius_Limit[0]*2 and oval_size<radius_Limit[1]*2:
                        num_six += 1
                        if is_blended_improved(result['image'])=='OK' and overlap_detection(processed_image):
                        # if is_blended_improved(result['image'])=='OK':    
                            if new_h5_file_path:
                                processed_images.append(processed_image)
                            selected_indices.append(i)
                            num_conform+=1
                            distances.append(distance)
                            circles_radius.append(circle_radius)
                            circles_arc.append(circle_arc)
                if i%1000 ==  0:
                    print(i)
            print("总数：",num_tol)
            print("成功检测：",num_success)
            print("小于6角秒：",num_six)
            print("符合总数：",num_conform)
            
            if new_h5_file_path:
                # 创建新H5文件
                with h5py.File(new_h5_file_path, 'w') as new_h5_file:

                    #new_h5_file.create_dataset('processed_images', data=processed_images)
                    new_h5_file.create_dataset('processed_images', shape=(len(processed_images),3,152,152))
                    for i in range(len(processed_images)):
                        new_h5_file['processed_images'][i]=processed_images[i]
                        
                    new_h5_file.create_dataset('circle_radius', data=circles_radius)
                    new_h5_file.create_dataset('oval_distances', data=distances)
                    new_h5_file.create_dataset('circle_arc', data=circles_arc)
                    
                    for key in keys:
                        
                        
                        if key != 'images':    
                            # 读取原始H5文件中的数据
                            data = h5_file[key][:]
                            # 根据索引列表获取要保留的数据
                            selected_data = data[selected_indices]
                            data_dict[key] = selected_data[:]
                            # 将数据保存到新的H5文件中
                            new_h5_file.create_dataset(key, data=selected_data)
                        else:
                            if save_old:
                                data=h5_file['images']
                                selected_data = data[selected_indices]
                                new_h5_file.create_dataset('images', shape=(len(selected_data),3,152,152))
                                for i in range(len(selected_data)):
                                    new_h5_file['images'][i]=selected_data[i]
                                
                print("新H5已生成")
            else:
                print("缺少H5路径")
                for key in keys:
                    if key != 'images':
                        # 读取原始H5文件中的数据
                        data = h5_file[key][:]
                        # 根据索引列表获取要保留的数据
                        selected_data = data[selected_indices]
                        data_dict[key] = selected_data[:]
                
            if new_csv_file_path:
                df = pd.DataFrame(data_dict)
                df['circles_radius'] =circles_radius
                df['oval_distances'] =distances
                df['circle_arc'] =circles_arc
                df.to_csv(new_csv_file_path, index=False)
                print("csv已生成")
            else:
                print("缺少csv路径")
        else:
            print("Key 'image' 不存在于H5文件中。")

# %% [markdown]
# ## South

# %%
h5_file_path = './label(10.07)/south/south_00_01_1.h5'
# new_h5_file_path = './Raw_data/north/north_01_02_unoverlap.h5'
new_csv_file_path = './processed_data/south/south_00_01_1_selected.csv'
# save_old = True

process_and_save_data(h5_file_path=h5_file_path,new_h5_file_path=None,new_csv_file_path=new_csv_file_path,save_old=False)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 总数： 199999
# 成功检测： 85240
# 小于6角秒： 40591
# 符合总数： 37961
# 缺少H5路径
# csv已生成

# %%
h5_file_path = './label(10.07)/south/south_00_01_2.h5'
# new_h5_file_path = './Raw_data/north/north_01_02_unoverlap.h5'
new_csv_file_path = './processed_data/south/south_00_01_2_selected.csv'

process_and_save_data(h5_file_path=h5_file_path,new_h5_file_path=None,new_csv_file_path=new_csv_file_path,save_old=False)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 总数： 132337
# 成功检测： 92350
# 小于6角秒： 74201
# 符合总数： 69529
# 缺少H5路径
# csv已生成

# %%
for i in range(1,9):
    h5_file_path = './label(10.07)/south/south_'+f"{i:02d}"+'_'+f"{i+1:02d}"+'.h5' 
    print(h5_file_path)
    new_csv_file_path = './processed_data/south/south_'+f"{i:02d}"+'_'+f"{i+1:02d}"+'_selected.csv'
    print(new_csv_file_path)
    process_and_save_data(h5_file_path, new_h5_file_path=None ,new_csv_file_path=new_csv_file_path,save_old=False)
# Out:
# ./label(10.07)/south/south_01_02.h5
# ./processed_data/south/south_01_02_selected.csv
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 总数： 139911
# 成功检测： 110666
# 小于6角秒： 99098
# 符合总数： 93176
# 缺少H5路径
# csv已生成
# ./label(10.07)/south/south_02_03.h5
# ./processed_data/south/south_02_03_selected.csv
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 总数： 21045
# 成功检测： 16669
# 小于6角秒： 16281
# 符合总数： 14846
# 缺少H5路径
# csv已生成
# ./label(10.07)/south/south_03_04.h5
# ./processed_data/south/south_03_04_selected.csv
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 总数： 16278
# 成功检测： 13592
# 小于6角秒： 13465
# 符合总数： 12399
# 缺少H5路径
# csv已生成
# ./label(10.07)/south/south_04_05.h5
# ./processed_data/south/south_04_05_selected.csv
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 总数： 12061
# 成功检测： 10428
# 小于6角秒： 10370
# 符合总数： 9626
# 缺少H5路径
# csv已生成
# ./label(10.07)/south/south_05_06.h5
# ./processed_data/south/south_05_06_selected.csv
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 总数： 8355
# 成功检测： 7407
# 小于6角秒： 7372
# 符合总数： 6958
# 缺少H5路径
# csv已生成
# ./label(10.07)/south/south_06_07.h5
# ./processed_data/south/south_06_07_selected.csv
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 总数： 5278
# 成功检测： 4780
# 小于6角秒： 4768
# 符合总数： 4511
# 缺少H5路径
# csv已生成
# ./label(10.07)/south/south_07_08.h5
# ./processed_data/south/south_07_08_selected.csv
# 0
# 1000
# 2000
# 3000
# 总数： 3306
# 成功检测： 3042
# 小于6角秒： 3039
# 符合总数： 2885
# 缺少H5路径
# csv已生成
# ./label(10.07)/south/south_08_09.h5
# ./processed_data/south/south_08_09_selected.csv
# 0
# 1000
# 2000
# 总数： 2554
# 成功检测： 2375
# 小于6角秒： 2374
# 符合总数： 2277
# 缺少H5路径
# csv已生成

# %% [markdown]
# ## North

# %%
h5_file_path =  './label(10.07)/north/north_00_01_1.h5'
# new_h5_file_path = './Raw_data/north/north_01_02_unoverlap.h5'
new_csv_file_path = './processed_data/north/north_00_01_1_selected.csv'

process_and_save_data(h5_file_path=h5_file_path,new_h5_file_path=None,new_csv_file_path=new_csv_file_path,save_old=False)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 总数： 199999
# 成功检测： 157891
# 小于6角秒： 99975
# 符合总数： 94919
# 缺少H5路径
# csv已生成

# %%
h5_file_path = './label(10.07)/north/north_00_01_2.h5'
# new_h5_file_path = './Raw_data/north/north_01_02_unoverlap.h5'
new_csv_file_path = './processed_data/north/north_00_01_2_selected.csv'

process_and_save_data(h5_file_path=h5_file_path,new_h5_file_path=None,new_csv_file_path=new_csv_file_path,save_old=False)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 总数： 23646
# 成功检测： 20445
# 小于6角秒： 19090
# 符合总数： 17511
# 缺少H5路径
# csv已生成

# %%
for i in range(1,15):
    h5_file_path = './label(10.07)/north/north_'+f"{i:02d}"+'_'+f"{i+1:02d}"+'.h5' 
    print(h5_file_path)
    new_csv_file_path = './processed_data/north/north_'+f"{i:02d}"+'_'+f"{i+1:02d}"+'_selected.csv'
    print(new_csv_file_path)
    process_and_save_data(h5_file_path, new_h5_file_path=None ,new_csv_file_path=new_csv_file_path,save_old=False)
# Out:
# ./label(10.07)/north/north_01_02.h5
# ./processed_data/north/north_01_02_selected.csv
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 总数： 12724
# 成功检测： 10970
# 小于6角秒： 10943
# 符合总数： 9963
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_02_03.h5
# ./processed_data/north/north_02_03_selected.csv
# 0
# 1000
# 2000
# 总数： 2169
# 成功检测： 1896
# 小于6角秒： 1891
# 符合总数： 1726
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_03_04.h5
# ./processed_data/north/north_03_04_selected.csv
# 0
# 总数： 360
# 成功检测： 264
# 小于6角秒： 264
# 符合总数： 246
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_04_05.h5
# ./processed_data/north/north_04_05_selected.csv
# 0
# 总数： 149
# 成功检测： 117
# 小于6角秒： 117
# 符合总数： 112
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_05_06.h5
# ./processed_data/north/north_05_06_selected.csv
# 0
# 总数： 109
# 成功检测： 88
# 小于6角秒： 87
# 符合总数： 81
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_06_07.h5
# ./processed_data/north/north_06_07_selected.csv
# 0
# 总数： 141
# 成功检测： 116
# 小于6角秒： 116
# 符合总数： 104
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_07_08.h5
# ./processed_data/north/north_07_08_selected.csv
# 0
# 总数： 73
# 成功检测： 61
# 小于6角秒： 61
# 符合总数： 56
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_08_09.h5
# ./processed_data/north/north_08_09_selected.csv
# 0
# 总数： 94
# 成功检测： 77
# 小于6角秒： 76
# 符合总数： 74
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_09_10.h5
# ./processed_data/north/north_09_10_selected.csv
# 0
# 总数： 75
# 成功检测： 62
# 小于6角秒： 62
# 符合总数： 56
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_10_11.h5
# ./processed_data/north/north_10_11_selected.csv
# 0
# 总数： 69
# 成功检测： 60
# 小于6角秒： 60
# 符合总数： 55
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_11_12.h5
# ./processed_data/north/north_11_12_selected.csv
# 0
# 总数： 81
# 成功检测： 53
# 小于6角秒： 52
# 符合总数： 44
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_12_13.h5
# ./processed_data/north/north_12_13_selected.csv
# 0
# 总数： 84
# 成功检测： 55
# 小于6角秒： 54
# 符合总数： 50
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_13_14.h5
# ./processed_data/north/north_13_14_selected.csv
# 0
# 总数： 89
# 成功检测： 38
# 小于6角秒： 38
# 符合总数： 30
# 缺少H5路径
# csv已生成
# ./label(10.07)/north/north_14_15.h5
# ./processed_data/north/north_14_15_selected.csv
# 0
# 总数： 49
# 成功检测： 6
# 小于6角秒： 6
# 符合总数： 6
# 缺少H5路径
# csv已生成

# %% [markdown]
# ## ssl

# %%
for i in range(9,37):
    h5_file_path = './label(10.07)/ssl/ssl-legacysurvey_b_'+f"{i:02d}"+'_'+f"{i+1:02d}"+'.h5' 
    print(h5_file_path)
    new_csv_file_path = './processed_data/ssl/ssl-legacysurvey_b_'+f"{i:02d}"+'_'+f"{i+1:02d}"+'_selected.csv'
    print(new_csv_file_path)
    process_and_save_data(h5_file_path, new_h5_file_path=None ,new_csv_file_path=new_csv_file_path,save_old=False)
# Out:
# ./label(10.07)/ssl/ssl-legacysurvey_b_09_10.h5
# ./processed_data/ssl/ssl-legacysurvey_b_09_10_selected.csv
# 0
# 1000
# 总数： 1996
# 成功检测： 1857
# 小于6角秒： 1854
# 符合总数： 1780
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_10_11.h5
# ./processed_data/ssl/ssl-legacysurvey_b_10_11_selected.csv
# 0
# 1000
# 总数： 1539
# 成功检测： 1427
# 小于6角秒： 1424
# 符合总数： 1376
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_11_12.h5
# ./processed_data/ssl/ssl-legacysurvey_b_11_12_selected.csv
# 0
# 1000
# 总数： 1129
# 成功检测： 1052
# 小于6角秒： 1050
# 符合总数： 1011
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_12_13.h5
# ./processed_data/ssl/ssl-legacysurvey_b_12_13_selected.csv
# 0
# 总数： 787
# 成功检测： 745
# 小于6角秒： 744
# 符合总数： 720
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_13_14.h5
# ./processed_data/ssl/ssl-legacysurvey_b_13_14_selected.csv
# 0
# 总数： 471
# 成功检测： 430
# 小于6角秒： 430
# 符合总数： 416
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_14_15.h5
# ./processed_data/ssl/ssl-legacysurvey_b_14_15_selected.csv
# 0
# 总数： 340
# 成功检测： 310
# 小于6角秒： 310
# 符合总数： 296
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_15_16.h5
# ./processed_data/ssl/ssl-legacysurvey_b_15_16_selected.csv
# 0
# 总数： 195
# 成功检测： 165
# 小于6角秒： 164
# 符合总数： 159
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_16_17.h5
# ./processed_data/ssl/ssl-legacysurvey_b_16_17_selected.csv
# 0
# 总数： 119
# 成功检测： 104
# 小于6角秒： 104
# 符合总数： 100
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_17_18.h5
# ./processed_data/ssl/ssl-legacysurvey_b_17_18_selected.csv
# 0
# 总数： 88
# 成功检测： 70
# 小于6角秒： 70
# 符合总数： 65
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_18_19.h5
# ./processed_data/ssl/ssl-legacysurvey_b_18_19_selected.csv
# 0
# 总数： 52
# 成功检测： 38
# 小于6角秒： 38
# 符合总数： 31
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_19_20.h5
# ./processed_data/ssl/ssl-legacysurvey_b_19_20_selected.csv
# 0
# 总数： 38
# 成功检测： 27
# 小于6角秒： 27
# 符合总数： 25
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_20_21.h5
# ./processed_data/ssl/ssl-legacysurvey_b_20_21_selected.csv
# 0
# 总数： 24
# 成功检测： 14
# 小于6角秒： 14
# 符合总数： 14
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_21_22.h5
# ./processed_data/ssl/ssl-legacysurvey_b_21_22_selected.csv
# 0
# 总数： 19
# 成功检测： 7
# 小于6角秒： 7
# 符合总数： 6
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_22_23.h5
# ./processed_data/ssl/ssl-legacysurvey_b_22_23_selected.csv
# 0
# 总数： 16
# 成功检测： 11
# 小于6角秒： 11
# 符合总数： 9
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_23_24.h5
# ./processed_data/ssl/ssl-legacysurvey_b_23_24_selected.csv
# 0
# 总数： 20
# 成功检测： 5
# 小于6角秒： 5
# 符合总数： 5
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_24_25.h5
# ./processed_data/ssl/ssl-legacysurvey_b_24_25_selected.csv
# 0
# 总数： 15
# 成功检测： 9
# 小于6角秒： 9
# 符合总数： 9
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_25_26.h5
# ./processed_data/ssl/ssl-legacysurvey_b_25_26_selected.csv
# 0
# 总数： 3
# 成功检测： 1
# 小于6角秒： 1
# 符合总数： 0
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_26_27.h5
# ./processed_data/ssl/ssl-legacysurvey_b_26_27_selected.csv
# 0
# 总数： 8
# 成功检测： 1
# 小于6角秒： 1
# 符合总数： 0
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_27_28.h5
# ./processed_data/ssl/ssl-legacysurvey_b_27_28_selected.csv
# 0
# 总数： 10
# 成功检测： 5
# 小于6角秒： 5
# 符合总数： 5
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_28_29.h5
# ./processed_data/ssl/ssl-legacysurvey_b_28_29_selected.csv
# 0
# 总数： 8
# 成功检测： 3
# 小于6角秒： 3
# 符合总数： 2
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_29_30.h5
# ./processed_data/ssl/ssl-legacysurvey_b_29_30_selected.csv
# 0
# 总数： 5
# 成功检测： 1
# 小于6角秒： 1
# 符合总数： 1
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_30_31.h5
# ./processed_data/ssl/ssl-legacysurvey_b_30_31_selected.csv
# 0
# 总数： 11
# 成功检测： 5
# 小于6角秒： 5
# 符合总数： 5
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_31_32.h5
# ./processed_data/ssl/ssl-legacysurvey_b_31_32_selected.csv
# 0
# 总数： 3
# 成功检测： 0
# 小于6角秒： 0
# 符合总数： 0
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_32_33.h5
# ./processed_data/ssl/ssl-legacysurvey_b_32_33_selected.csv
# 0
# 总数： 5
# 成功检测： 1
# 小于6角秒： 1
# 符合总数： 1
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_33_34.h5
# ./processed_data/ssl/ssl-legacysurvey_b_33_34_selected.csv
# 0
# 总数： 4
# 成功检测： 1
# 小于6角秒： 1
# 符合总数： 1
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_34_35.h5
# ./processed_data/ssl/ssl-legacysurvey_b_34_35_selected.csv
# 0
# 总数： 1
# 成功检测： 0
# 小于6角秒： 0
# 符合总数： 0
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_35_36.h5
# ./processed_data/ssl/ssl-legacysurvey_b_35_36_selected.csv
# 0
# 总数： 2
# 成功检测： 1
# 小于6角秒： 1
# 符合总数： 0
# 缺少H5路径
# csv已生成
# ./label(10.07)/ssl/ssl-legacysurvey_b_36_37.h5
# ./processed_data/ssl/ssl-legacysurvey_b_36_37_selected.csv
# 0
# 总数： 2
# 成功检测： 1
# 小于6角秒： 1
# 符合总数： 1
# 缺少H5路径
# csv已生成

# %%
# 批量处理H5文件
for i in range(2,9):
    h5_file_path = './Raw_data/south_'+f"{i:02d}"+'_'+f"{i+1:02d}"+'.h5' 
    print(h5_file_path)
    new_csv_file_path = './Raw_data/south_'+f"{i:02d}"+'_'+f"{i+1:02d}"+'_selected.csv'
    print(new_csv_file_path)
    process_and_save_data(h5_file_path, new_h5_file_path=None ,new_csv_file_path=new_csv_file_path)

# %%
# 查看新生成的H5 key
with h5py.File(new_h5_file_path, 'r') as data:
    for key in data.keys():
        print(f"{key} is: {data[key][0].shape}")

# %%
# new_h5_file_path = './Raw_data/south_05_06_processed.h5'
n =60

data = h5py.File(new_h5_file_path,"r")


# 设置子图的行数和列数
rows = 10
cols = 2

images_list_1 = data['images'][n:n+rows]
images_list_2 = data['processed_images'][n:n+rows]
info_list_1 = list(range(n,n+rows))
# info_list_2 = data['fit_rates'][1048:1058]



# 创建一个新的图像窗口，并设置子图布局
fig, axes = plt.subplots(rows, cols, figsize=(10, 20))

# 将两个图像列表进行对照显示在不同的子图中，并添加信息标签
for i in range(rows):
    axes[i, 0].imshow(to_rgb.dr2_rgb( images_list_1[i],['g','r','z']), cmap='gray')
    axes[i, 0].set_title(f"Image {info_list_1[i]}")
    # axes[i, 0].annotate(info_list_1[i], xy=(0.5, 1.02), xytext=(0, 5), textcoords='offset points',
    #                     ha='center', va='bottom', fontsize=10)
    axes[i, 0].axis('off')
    
    axes[i, 1].imshow(to_rgb.dr2_rgb(images_list_2[i],['g','r','z'], cmap='gray'))
    axes[i, 1].set_title(f"ImageRaw")
    # axes[i, 1].annotate(info_list_2[i], xy=(0.5, 1.02), xytext=(0, 5), textcoords='offset points',
    #                     ha='center', va='bottom', fontsize=10)
    axes[i, 1].axis('off')

# 显示图像
plt.tight_layout()
plt.show()
